# %%
# !pip install roboflow ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 88.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 116.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="jLBhika5AikpXmmbGjbY")
project = rf.workspace("project-jyxn5").project("weed-detection-l8mtq-nyyut")
dataset = project.version(1).download("yolov8")   # v1
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Weed-Detection-1 in yolov8:: 100%|██████████| 14302/14302 [00:05<00:00, 2456.26it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !ls /content/Weed-Detection-1
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !cat /content/Weed-Detection-1/data.yaml
# Out:
# names:
# - Weeds
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: weed-detection-l8mtq-nyyut
#   url: https://universe.roboflow.com/project-jyxn5/weed-detection-l8mtq-nyyut/dataset/1
#   version: 1
#   workspace: project-jyxn5
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
import yaml

yaml_path = "/content/Weed-Detection-1/data.yaml"

with open(yaml_path, "r") as f:
    data = yaml.safe_load(f)

data["train"] = "/content/Weed-Detection-1/train/images"
data["val"]   = "/content/Weed-Detection-1/valid/images"
data["test"]  = "/content/Weed-Detection-1/test/images"

with open(yaml_path, "w") as f:
    yaml.dump(data, f)

print("YAML updated successfully!")
# Out:
# YAML updated successfully!

# %%
# !cat /content/Weed-Detection-1/data.yaml
# Out:
# names:
# - Weeds
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: weed-detection-l8mtq-nyyut
#   url: https://universe.roboflow.com/project-jyxn5/weed-detection-l8mtq-nyyut/dataset/1
#   version: 1
#   workspace: project-jyxn5
# test: /content/Weed-Detection-1/test/images
# train: /content/Weed-Detection-1/train/images
# val: /content/Weed-Detection-1/valid/images

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/Weed-Detection-1/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# ...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !find . -name "best.pt"
# Out:
# ./runs/detect/train/weights/best.pt

# %%
from google.colab import files
files.download("./runs/detect/train/weights/best.pt")
